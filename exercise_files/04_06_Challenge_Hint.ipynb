# %% [markdown]
# ## ASCII Art Encoding

# %% [markdown]
# ### Challenge Hints!

# %% [markdown]
# **Hint 1:** While iterating through each character of a string, we can print out when a string has "switched" from one character to another:

# %%
stringVal = 'AAAAABBBBBCCCCCA'

prevChar = None
for char in stringVal:
    counter = counter + 1
    if char != prevChar:
        print(f'New character is {char}')       
    prevChar = char
# Out:
# New character is A
# New character is B
# New character is C
# New character is A

# %% [markdown]
# **Hint 2:** Remember that you can multiply a string by a number!

# %%
'A'*5
# Out:
# 'AAAAA'

# %%
def encodeString(stringVal):
    pass

def decodeString(encodedList):
    pass

# %%
art = '''
mmm
                                                                                
                                                                                
                               %%%%%%%%%%%%%%%%%%%                              
                        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%                       
                    %%%%%%%%                         %%%%%%%%                   
                %%%%%%%                                   %%%%%%                
              %%%%%%                                         %%%%%%             
           %%%%%%                                               %%%%%           
          %%%%%                                                   %%%%%         
        %%%%%                                                       %%%%%       
       %%%%                 %%%%%              %%%%%                  %%%%      
      %%%%                 %%%%%%%            %%%%%%%                  %%%%     
     %%%%                  %%%%%%%            %%%%%%%                   %%%%    
    %%%%                   %%%%%%%            %%%%%%%                    %%%%   
    %%%%                    %%%%%              %%%%%                     %%%%   
   %%%%                                                                   %%%%  
   %%%%                                                                   %%%%  
   %%%%                                                                   %%%%  
   %%%%                                                      %%%%        %%%%   
    %%%%       %%%%%%                                        %%%%%       %%%%   
    %%%%         %%%%                                       %%%%        %%%%    
     %%%%         %%%%                                     %%%%         %%%%    
      %%%%         %%%%%                                  %%%%         %%%%     
       %%%%%         %%%%%                             %%%%%         %%%%%      
        %%%%%          %%%%%%                        %%%%%          %%%%        
          %%%%%           %%%%%%%               %%%%%%%           %%%%%         
            %%%%%             %%%%%%%%%%%%%%%%%%%%%             %%%%%           
              %%%%%%%                                        %%%%%              
                 %%%%%%%                                 %%%%%%%                
                     %%%%%%%%%                     %%%%%%%%%                    
                          %%%%%%%%%%%%%%%%%%%%%%%%%%%%%                         
                                   %%%%%%%%%%%%                                 
                                                                                
                                                                                 

'''

# %%
encodedString = encodeString(art)

# %%
decodeString(encodedString)

# %%
x=(art.splitlines())

# %%
x
# Out:
# ['',
#  'mmm',
#  '',
#  '',
#  '                               %%%%%%%%%%%%%%%%%%%                              ',
#  '                        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%                       ',
#  '                    %%%%%%%%                         %%%%%%%%                   ',
#  '                %%%%%%%                                   %%%%%%                ',
#  '              %%%%%%                                         %%%%%%             ',
#  '           %%%%%%                                               %%%%%           ',
#  '          %%%%%                                                   %%%%%         ',
#  '        %%%%%                                                       %%%%%       ',
#  '       %%%%                 %%%%%              %%%%%                  %%%%      ',
#  '      %%%%                 %%%%%%%            %%%%%%%                  %%%%     ',
#  '     %%%%                  %%%%%%%            %%%%%%%                   %%%%    ',
# ...

# %%
x
# Out:
# ['',
#  'mmm',
#  '',
#  '',
#  '                               %%%%%%%%%%%%%%%%%%%                              ',
#  '                        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%                       ',
#  '                    %%%%%%%%                         %%%%%%%%                   ',
#  '                %%%%%%%                                   %%%%%%                ',
#  '              %%%%%%                                         %%%%%%             ',
#  '           %%%%%%                                               %%%%%           ',
#  '          %%%%%                                                   %%%%%         ',
#  '        %%%%%                                                       %%%%%       ',
#  '       %%%%                 %%%%%              %%%%%                  %%%%      ',
#  '      %%%%                 %%%%%%%            %%%%%%%                  %%%%     ',
#  '     %%%%                  %%%%%%%            %%%%%%%                   %%%%    ',
# ...

# %%
for number in range(1, 6):
    if number % 2 == 0:  # Check if the number is even
        print(f"Skipping even number: {number}")
        continue  # Skip the rest of the current iteration and move to the next
    print(f"Processing odd number: {number}")
# Out:
# Processing odd number: 1
# Skipping even number: 2
# Processing odd number: 3
# Skipping even number: 4
# Processing odd number: 5

# %%
for element in ("", 6, None, "Hello", 0.0," "):
    if element == "" or element == None:  # Check for empty string or None
        print(f"Skipping element: \'{element}\'")
        continue  # Skip the rest of the current iteration and move to the next
    print(f"Processing element: \'{element}\'")
# Out:
# Skipping element: ''
# Processing element: '6'
# Skipping element: 'None'
# Processing element: 'Hello'
# Processing element: '0.0'
# Processing element: ' '
